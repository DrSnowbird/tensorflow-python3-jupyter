# %%
# !pip install transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      |████████████████████████████████| 1.3 MB 1.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 883 kB 2.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.1 MB 1.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 2.9 MB 1.7 MB/s eta 0:00:01
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-py3-none-any.whl size=893259 sha256=469ad1cf4ec534d5873eb35429ef2c9689aa29e81f44cec7bcd473b455246d69
#   Stored in directory: /home/developer/.cache/pip/wheels/49/25/98/cdea9c79b2d9a22ccc59540b1784b67f06b633378e97f58da2
# Successfully built sacremoses
# ...

# %%
 from transformers import pipeline
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
# !pip freeze
# Out:
# absl-py==0.11.0
# appdirs==1.4.4
# argon2-cffi==20.1.0
# asn1crypto==0.24.0
# astunparse==1.6.3
# async-generator==1.10
# attrs==20.3.0
# backcall==0.2.0
# beautifulsoup4==4.6.0
# bert-serving-client==1.10.0
# bert-serving-server==1.10.0
# bleach==3.2.1
# blis==0.4.1
# boto3==1.16.18
# botocore==1.19.18
# cached-property==1.5.2
# cachetools==4.1.1
# catalogue==1.0.0
# certifi==2020.11.8
# cffi==1.14.3
# chardet==3.0.4
# click==7.1.2
# cloudpickle==1.6.0
# cryptography==2.1.4
# cycler==0.10.0
# cymem==2.0.4
# dataclasses==0.8
# decorator==4.4.2
# defusedxml==0.6.0
# distlib==0.3.1
# entrypoints==0.3
# filelock==3.0.12
# findspark==1.4.2
# fire==0.3.1
# Flask==1.1.2
# funcy==1.15
# future==0.18.2
# gast==0.3.3
# gensim==3.8.3
# google-auth==1.23.0
# google-auth-oauthlib==0.4.2
# google-pasta==0.2.0
# GPUtil==1.4.0
# grpcio==1.33.2
# h5py==2.10.0
# html5lib==0.999999999
# httpie==2.2.0
# hyperopt==0.2.5
# idna==2.10
# importlib-metadata==2.0.0
# importlib-resources==3.0.0
# ...
